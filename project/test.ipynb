# %% [markdown]
# # 测试

# %%
from inference import recognize_char, recognize_chars
import keras

# %%
# 加载训练好的模型
loaded_model = keras.models.load_model('./save_models/chars_trained_model.h5')

# %%
# 模型结构
loaded_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 20, 20, 32)        320
# _________________________________________________________________
# activation_1 (Activation)    (None, 20, 20, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 18, 18, 32)        9248
# _________________________________________________________________
# activation_2 (Activation)    (None, 18, 18, 32)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 9, 9, 32)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 9, 9, 32)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 9, 9, 64)          18496
# _________________________________________________________________
# activation_3 (Activation)    (None, 9, 9, 64)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 7, 7, 64)          36928
# _________________________________________________________________
# activation_4 (Activation)    (None, 7, 7, 64)          0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 3, 3, 64)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 3, 3, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 576)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               295424
# _________________________________________________________________
# activation_5 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 65)                33345
# _________________________________________________________________
# activation_6 (Activation)    (None, 65)                0
# =================================================================
# Total params: 393,761
# Trainable params: 393,761
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 模型结构
#
# **采用卷积神经网络进行构建模型**
# ![model_structure](./model_structure.png)

# %% [markdown]
# ## 单一图片识别

# %%
# 识别单张图片的字符
recognize_char(path='.\\test_images\\test_lu.jpg', model=loaded_model)

# %% [markdown]
# ## 目录下多图片识别

# %%
# 识别目录下所有图片的字符 字符图片来源于原数据集
recognize_chars(dir_path='.\\test_images\\original', model=loaded_model)

# %%
# 识别目录下所有图片的字符 字符图片来源于图像增加生成的图片
recognize_chars(dir_path='.\\test_images\\generated', model=loaded_model)

# %%
# 生成模型结构图
# keras.utils.plot_model(loaded_model, to_file='model.png', show_shapes=True)

# %%
import Augmentor
# 图像增强生成测试图像
p = Augmentor.Pipeline('./test_images/original')
# 对字符进行一定程度的变形
p.random_distortion(probability=1, grid_width=4, grid_height=4, magnitude=1)
# 生成400个测试样本
p.sample(400)
